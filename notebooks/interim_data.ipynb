# %%
from adapters.load import interim

# %%
df = interim()
print(f"Shape: {df.shape}")
print(f"Columns: {df.columns.tolist()[:10]}...")  # First 10
df.head()
# Out:
# Shape: (1460, 76)
# Columns: ['MSSubClass', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF']...
#    MSSubClass   LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0    0.073375 -0.207142     0.651479    -0.517200   1.050994      0.878668
# 1   -0.872563 -0.091886    -0.071836     2.179628   0.156734     -0.429577
# 2    0.073375  0.073480     0.651479    -0.517200   0.984752      0.830215
# 3    0.309859 -0.096897     0.651479    -0.517200  -1.863632     -0.720298
# 4    0.073375  0.375148     1.374795    -0.517200   0.951632      0.733308
#
#    MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  Functional  GarageType  \
# 0    0.514104    0.575425   -0.288653  -0.944591  ...         Typ      Attchd
# 1   -0.570750    1.171992   -0.288653  -0.641228  ...         Typ      Attchd
# 2    0.325915    0.092907   -0.288653  -0.301643  ...         Typ      Attchd
# ...
